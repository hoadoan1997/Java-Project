# %% [markdown]
# <a href="https://colab.research.google.com/github/hoadoan1997/Address-Management/blob/master/JAV_Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/conanak99/jav-py
# Out:
# Cloning into 'jav-py'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 15 (delta 3), reused 4 (delta 1), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
#Import Libraries
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Read file Json and create Dataframe
df = pd.read_json("jav-py/acctress.json")
df.head()
# Out:
#    id          name japanName hiragana  bust  waist   hip  height    birthday  \
# 0   3  Kitagawa Yui      北川ゆい   きたがわゆい  95.0   60.0  88.0     NaN  1980-12-14
# 1   4         Akira     Akira      あきら  90.0   58.0  86.0   157.0  1978-08-15
# 2   6        Cocolo    COCOLO      こころ  96.0   55.0  85.0   168.0  1982-07-07
# 3   8         Saiko     Saiko      さいこ  80.0   59.0  82.0   162.0  1983-04-12
# 4  11     Aida Momo     あいだもも    あいだもも  82.0   55.0  89.0   162.0  1970-06-18
#
#   blood_type     hobby prefectures
# 0         AB  クラシックバレエ        None
# 1          A    水泳、ゴルフ         東京都
# 2          B      パソコン         茨城県
# 3          O    料理、大食い         東京都
# 4          A    エアロビクス         東京都

# %%
#View Dataframe 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11186 non-null  int64
#  1   name         11186 non-null  object
#  2   japanName    11186 non-null  object
#  3   hiragana     11186 non-null  object
#  4   bust         6456 non-null   float64
#  5   waist        6436 non-null   float64
#  6   hip          6428 non-null   float64
#  7   height       5012 non-null   float64
#  8   birthday     4031 non-null   datetime64[ns]
#  9   blood_type   3171 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  4471 non-null   object
#  12  age          4031 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
#Create Age column 
df['birthday'] = pd.to_datetime(df['birthday'], yearfirst= True)
df['age'] = 2022 - pd.DatetimeIndex(df['birthday']).year

df.head()
# Out:
#    id          name japanName hiragana  bust  waist   hip  height   birthday  \
# 0   3  Kitagawa Yui      北川ゆい   きたがわゆい  95.0   60.0  88.0     NaN 1980-12-14
# 1   4         Akira     Akira      あきら  90.0   58.0  86.0   157.0 1978-08-15
# 2   6        Cocolo    COCOLO      こころ  96.0   55.0  85.0   168.0 1982-07-07
# 3   8         Saiko     Saiko      さいこ  80.0   59.0  82.0   162.0 1983-04-12
# 4  11     Aida Momo     あいだもも    あいだもも  82.0   55.0  89.0   162.0 1970-06-18
#
#   blood_type     hobby prefectures   age
# 0         AB  クラシックバレエ        None  42.0
# 1          A    水泳、ゴルフ         東京都  44.0
# 2          B      パソコン         茨城県  40.0
# 3          O    料理、大食い         東京都  39.0
# 4          A    エアロビクス         東京都  52.0

# %%
#Search actress is youngest
df[df['age'] == df.age.min()]
# Out:
#            id          name japanName hiragana  bust  waist   hip  height  \
# 9826  1059504    Maki Izuna      槙いずな    まきいずな  80.0   55.0  84.0   148.0
# 9933  1061822  Takeda Erena     武田エレナ   たけだえれな   NaN    NaN   NaN     NaN
#
#        birthday blood_type hobby prefectures   age
# 9826 2001-01-27       None    読書         東京都  21.0
# 9933 2001-08-08       None  None         静岡県  21.0

# %%
#Search actress is oldest
df[df['age'] == df.age.max()]
# Out:
#          id           name japanName hiragana  bust  waist   hip  height  \
# 10655  8070  Huzita Ryouko      藤田亮子  ふじたりょうこ  86.0   60.0  86.0   156.0
#
#         birthday blood_type hobby prefectures   age
# 10655 1955-02-18       None  None        None  67.0

# %%
#Describe Data
df.describe()
# Out:
#                  id         bust        waist          hip       height  \
# count  1.118600e+04  6456.000000  6436.000000  6428.000000  5012.000000
# mean   4.852872e+05    87.094253    58.898229    86.289203   158.713148
# std    5.076289e+05     6.155405     3.176163     3.829804     5.814022
# min    3.000000e+00    51.000000    48.000000    54.000000   134.000000
# 25%    7.189000e+03    83.000000    58.000000    84.000000   155.000000
# 50%    2.678500e+04    86.000000    58.000000    86.000000   158.000000
# 75%    1.026770e+06    90.000000    60.000000    88.000000   163.000000
# max    1.063061e+06   153.000000   100.000000   125.000000   182.000000
#
#                 age
# count  11186.000000
# mean      35.974701
# std        4.548903
# min       21.000000
# 25%       35.000000
# 50%       35.000000
# 75%       35.000000
# max       67.000000

# %%
#Fille data null in Age = 35
df['age'] = df.age.fillna(35)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11186 non-null  int64
#  1   name         11186 non-null  object
#  2   japanName    11186 non-null  object
#  3   hiragana     11186 non-null  object
#  4   bust         6456 non-null   float64
#  5   waist        6436 non-null   float64
#  6   hip          6428 non-null   float64
#  7   height       5012 non-null   float64
#  8   birthday     4031 non-null   datetime64[ns]
#  9   blood_type   3171 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  4471 non-null   object
#  12  age          11186 non-null  float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
#Plot age data, mean age are between 35 to 42
plt.figure(figsize=(15, 10))
sns.displot(df.age.dropna())

# %%
df.describe()
# Out:
#                  id         bust        waist          hip       height  \
# count  1.118600e+04  6456.000000  6436.000000  6428.000000  5012.000000
# mean   4.852872e+05    87.094253    58.898229    86.289203   158.713148
# std    5.076289e+05     6.155405     3.176163     3.829804     5.814022
# min    3.000000e+00    51.000000    48.000000    54.000000   134.000000
# 25%    7.189000e+03    83.000000    58.000000    84.000000   155.000000
# 50%    2.678500e+04    86.000000    58.000000    86.000000   158.000000
# 75%    1.026770e+06    90.000000    60.000000    88.000000   163.000000
# max    1.063061e+06   153.000000   100.000000   125.000000   182.000000
#
#                age
# count  4031.000000
# mean     37.704788
# std       7.262923
# min      21.000000
# 25%      33.000000
# 50%      37.000000
# 75%      42.000000
# max      67.000000

# %%
#Plot histogram by bust
df.bust.plot.hist(figsize=(15, 6), bins=50)

# %%
#Search name contains Mikami
df[df.name.str.contains("Mikami")]
# Out:
#            id            name japanName hiragana  bust  waist   hip  height  \
# 94       1117     Mikami Sati      三上さち    みかみさち   NaN    NaN   NaN     NaN
# 95       1118     Mikami Syun     三上しゅん   みかみしゅん   NaN    NaN   NaN     NaN
# 96       1119      Mikami Ran       三上蘭    みかみらん  84.0   59.0  86.0     NaN
# 625     13127     Mikami Runa      美神ルナ    みかみるな  88.0   58.0  85.0   163.0
# 677     13586    Mikami Yuuki      三上夕希   みかみゆうき  86.0   65.0  89.0   168.0
# 1762    20124     Mikami Seri      美上セリ    みかみせり  83.0   58.0  82.0   160.0
# 2258    22162     Mikami Nana      美神奈々    みかみなな   NaN    NaN   NaN     NaN
# 3207    26885   Mikami Sihori     三神しほり   みかみしほり   NaN    NaN   NaN     NaN
# 3305    27668     Mikami Rion     三上リオン   みかみりおん  88.0   59.0  82.0   147.0
# 3391    27889    Mikami Seira      美神聖良   みかみせいら   NaN    NaN   NaN     NaN
# 3470    28354   Mikami Sayuri     美神さゆり   みかみさゆり   NaN    NaN   NaN     NaN
# 3720  1000282     Mikami Airi     三上あいり   みかみあいり  85.0   58.0  84.0   165.0
# 6473  1025073     Mikami Yuzu      三神ゆず    みかみゆず   NaN    NaN   NaN     NaN
# 6524  1025577     Mikami Riho      三上里穂    みかみりほ   NaN    NaN   NaN     NaN
# 6541  1025773      Mikami Aya      美神あや    みかみあや  88.0   58.0  90.0   157.0
# 7237  1030262      Mikami Yua      三上悠亜    みかみゆあ  84.0   58.0  88.0   159.0
# 7859  1034620    Mikami Erika     三上絵理香   みかみえりか   NaN    NaN   NaN     NaN
# 7948     4690   Mikami Syouko      三上翔子  みかみしょうこ  83.0   61.0  88.0   156.0
# 8403  1039029  Mikami Chinatu      三上千夏   みかみちなつ   NaN    NaN   NaN     NaN
#
#        birthday blood_type             hobby prefectures   age
# 94          NaT       None              None        None   NaN
# 95          NaT       None              None        None   NaN
# 96   1982-12-16          O              None        None  40.0
# 625  1984-06-01          O  ダンス、旅行、ダイビング、英会話         東京都  38.0
# 677         NaT       None              None        None   NaN
# 1762 1987-03-15          B        ショッピング、ダーツ         東京都  35.0
# 2258        NaT       None              None        None   NaN
# 3207        NaT       None              None               NaN
# 3305        NaT       None                                 NaN
# 3391        NaT       None              None               NaN
# 3470        NaT       None              None               NaN
# 3720 1988-09-18         AB           読書、映画鑑賞         北海道  34.0
# 6473        NaT       None              None        None   NaN
# 6524        NaT       None              None        None   NaN
# 6541 1984-10-10       None              None        None  38.0
# 7237 1993-08-16       None         アイドルDVD鑑賞        None  29.0
# 7859        NaT       None              None        None   NaN
# 7948 1982-02-18          B              None         東京都  40.0
# 8403        NaT       None              None        None   NaN

# %%
#Search actress by bust
df[df['bust'] >= 88]
# Out:
#           id            name   japanName         hiragana   bust  waist   hip  \
# 0          3    Kitagawa Yui        北川ゆい           きたがわゆい   95.0   60.0  88.0
# 1          4           Akira       Akira              あきら   90.0   58.0  86.0
# 2          6          Cocolo      COCOLO              こころ   96.0   55.0  85.0
# 5         13    Asano Kurumi      あさのくるみ           あさのくるみ   94.0    NaN   NaN
# 7         23             Eve    イヴ（神代弓子）     いう゛（くましろゆみこ）   88.0   58.0  86.0
# ...      ...             ...         ...              ...    ...    ...   ...
# 11171  10467   Yukino Mahiru       雪乃まひる           ゆきのまひる  101.0   60.0  90.0
# 11175  10495   Oohara Satomi        大原里美          おおはらさとみ   90.0   58.0  90.0
# 11182  10540   Mizimoto Miwa        藤本美羽           ふじもとみわ   88.0   58.0  87.0
# 11184  10544  Sugimoto Ayako  希崎圭蓮（杉本彩子）  きさきかれん（すぎもとあやこ）   90.0   63.0  87.0
# 11185  10550    Akatuki Runa        紅月ルナ           あかつきるな   88.0   59.0  86.0
#
#        height   birthday blood_type                   hobby prefectures   age
# 0         NaN 1980-12-14         AB                クラシックバレエ        None  42.0
# 1       157.0 1978-08-15          A                  水泳、ゴルフ         東京都  44.0
# 2       168.0 1982-07-07          B                    パソコン         茨城県  40.0
# 5         NaN        NaT       None                    None        None   NaN
# 7       160.0 1963-11-22          O  スキューバダイビング、パソコン、衣装デザイン         静岡県  59.0
# ...       ...        ...        ...                     ...         ...   ...
# 11171   159.0 1982-03-03          O               何処でも寝れること         千葉県  40.0
# 11175     NaN 1979-07-05          O                剣道、料理、水泳         千葉県  43.0
# 11182   153.0 1984-08-28          O               ショッピング、料理         東京都  38.0
# 11184   150.0        NaT       None                    None        None   NaN
# 11185   161.0 1984-06-04          B               柔軟体操、カラオケ         東京都  38.0
#
# [2491 rows x 13 columns]

# %%
#Search actress with bust, hip and age
df[(df['bust'] >= 88) & (df['hip'] >= 90) & (df['age'] <= 28)]
# Out:
#            id             name   japanName      hiragana   bust  waist   hip  \
# 5415  1016575      Kitano Tika        北乃ちか         きたのちか  101.0   61.0  91.0
# 5875  1020830    Momono Homare         桃乃誉        もものほまれ   95.0   64.0  90.0
# 5963  1021562     Ogawa Mitiru       小川みちる        おがわみちる   88.0   63.0  90.0
# 6066  1022129     Tukada Siori        塚田詩織        つかだしおり  101.0   60.0  95.0
# 6193  1023222     Miyazaki Aya        宮崎あや        みやざきあや   88.0   57.0  95.0
# 7299  1030343   Utasima Honoka       詩島ほのか       うたしまほのか   88.0   63.0  90.0
# 7555  1032166      Misuzu Rina        美涼りな         みすずりな   88.0   59.0  90.0
# 7676  1032840    Minami Manaka        南真菜果        みなみまなか   95.0   62.0  91.0
# 7711  1033176       Seta Kanae        瀬田奏恵         せたかなえ   90.0   60.0  90.0
# 7741  1033478   Nakamura Osina        中村推菜       なかむらおしな   95.0   61.0  91.0
# 7746  1033660    Mizusawa Riko        水澤りこ        みずさわりこ   95.0   61.0  92.0
# 7774  1033955   Matusita Miori        松下美織       まつしたみおり   90.0   63.0  90.0
# 7794  1034082    Niiduki Sanae       新月さなえ       にいづきさなえ   98.0   60.0  90.0
# 7856  1034542       Aoyama Ren        青山れん        あおやまれん   89.0   61.0  93.0
# 7995  1035509     Okazawa Rina        岡沢リナ        おかざわりな   98.0   59.0  92.0
# 8038  1035807      Sanada Miki        真田美樹         さなだみき   90.0   60.0  90.0
# 8076  1036103      Hukada Nana        深田ナナ         ふかだなな  107.0   63.0  95.0
# 8124  1036441      Hinata Runa        日向るな         ひなたるな   88.0   59.0  90.0
# 8312  1038133       Kozima Ami        小嶋亜美         こじまあみ   88.0   60.0  93.0
# 8377  1038713  Kikukawa Mituha  みつ葉（菊川みつ葉）  みつは（きくかわみつは）   94.0   58.0  93.0
# 8515  1040443      Taira Marin         平真凛        たいらまりん  103.0   57.0  91.0
# 8612  1041267  Hosimiya Minami       星宮みなみ       ほしみやみなみ   95.0   70.0  93.0
# 8651  1041759      Yuuri Maina       優梨まいな        ゆうりまいな   92.0   67.0  97.0
# 8818  1043785      Satuki Towa        沙月とわ         さつきとわ   90.0   62.0  90.0
# 9043  1046398      Kuruse Airi       来瀬あいり        くるせあいり   90.0   61.0  92.0
# 9253  1049135  Nonohara Nazuna      野々原なずな       ののはらなずな   92.0   60.0  90.0
# 9323  1050760  Minagawa Tiharu      みながわ千遥       みながわちはる   88.0   60.0  93.0
# 9327  1050830    Takami Haruka       高美はるか        たかみはるか   88.0   60.0  90.0
# 9328  1050836    Sanada Mizuki       真田みづ稀        さなだみづき   93.0   60.0  90.0
# 9366  1051751  Morimoto Tugumi       森本つぐみ       もりもとつぐみ   90.0   60.0  90.0
# 9413  1052739   Motizuki Ayaka       望月あやか       もちづきあやか   90.0   60.0  92.0
# 9420  1052865     Koga Matsuna       古賀まつな         こがまつな   92.0   60.0  91.0
# 9526  1052929    Kamiki Mahoro       神木まほろ        かみきまほろ   89.0   60.0  95.0
# 9554  1053417       Masiro Mao        真白真緒         ましろまお   96.0   56.0  91.0
# 9833  1059565        Maeda Moa        前田桃杏         まえだもあ   98.0   59.0  92.0
#
#       height   birthday blood_type                  hobby prefectures   age
# 5415   153.0 1994-05-28       None   カラオケ、体を動かす事、バスケットボール         東京都  28.0
# 5875   155.0 1994-02-09          O           ピアノ、カラオケ、バスケ         東京都  28.0
# 5963   153.0 1994-09-09          O           特技コスプレ、フラフープ         宮城県  28.0
# 6066   155.0 1994-03-23          A      読書、舞台鑑賞、英会話、タイピング         北海道  28.0
# 6193   162.0 1995-06-20       None               音楽、お菓子作り         東京都  27.0
# 7299     NaN 1996-03-03          O                 マンガ、料理         千葉県  26.0
# 7555   157.0 1994-07-10          A            極真空手、ウォーキング         東京都  28.0
# 7676   166.0 1995-07-20       None        ドミノ倒し、バレーボール、英語         東京都  27.0
# 7711   166.0 1994-04-06          A         ストレッチ、料理、お菓子作り        神奈川県  28.0
# 7741   172.0 1998-11-19       None                  運動・ヨガ        None  24.0
# 7746   158.0 1997-02-11       None                    新体操        None  25.0
# 7774   168.0 1995-08-06       None                 ショッピング         東京都  27.0
# 7794   151.0 1996-08-08       None                   None        None  26.0
# 7856   160.0 1995-03-05       None                   None        None  27.0
# 7995   156.0 1996-07-07       None          音楽鑑賞、身体を動かすこと        None  26.0
# 8038   166.0 1996-03-14       None         ギター、ソフトボール、バスケ         東京都  26.0
# 8076   165.0 1996-12-30       None                   None        None  26.0
# 8124   170.0 1996-07-07          O               食べること（肉）        神奈川県  26.0
# 8312     NaN 1997-12-07       None               アイドル追っかけ        None  25.0
# 8377   166.0 1997-11-25       None                   None         東京都  25.0
# 8515     NaN 1998-07-06       None                    ダンス        None  24.0
# 8612   160.0 1994-08-21          B                 買い物、料理         東京都  28.0
# 8651   155.0 1995-05-31          B            絵を描く事、競馬、鉄道         埼玉県  27.0
# 8818   167.0 1998-01-18       None  アニメ鑑賞、ゲーム、水泳、クラシックバレー         新潟県  24.0
# 9043   156.0 1994-11-29          A            ドライブ、買い物、習字         東京都  28.0
# 9253   153.0 1999-04-02       None                イラスト、読書        None  23.0
# 9323   157.0 1997-12-28       None        筋トレ、美容、海外ドラマ、洋楽         富山県  25.0
# 9327   158.0 1998-08-08       None                     語学        None  24.0
# 9328   166.0 1996-03-14       None         ギター、ソフトボール、バスケ         埼玉県  26.0
# 9366   152.0 1999-08-07       None            カラオケ、アイドル鑑賞        None  23.0
# 9413     NaN 1995-11-30          O       オ〇ニー、食べる事、空手、潮吹き         青森県  27.0
# 9420   155.0 1999-01-08       None         読書、ピアノ、音楽鑑賞、料理         新潟県  23.0
# 9526   160.0 1998-10-10          A                   None         愛知県  24.0
# 9554   163.0 1997-11-08         AB                   None         東京都  25.0
# 9833   160.0 2000-10-07       None                   None        None  22.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11186 non-null  int64
#  1   name         11186 non-null  object
#  2   japanName    11186 non-null  object
#  3   hiragana     11186 non-null  object
#  4   bust         6456 non-null   float64
#  5   waist        6436 non-null   float64
#  6   hip          6428 non-null   float64
#  7   height       5012 non-null   float64
#  8   birthday     4031 non-null   datetime64[ns]
#  9   blood_type   3171 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  4471 non-null   object
#  12  age          4031 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 1.1+ MB

# %%
from wordcloud import WordCloud

# %%
hobby_df = df[df.hobby.notnull()]

# %%
hobby_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3730 entries, 0 to 11185
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           3730 non-null   int64
#  1   name         3730 non-null   object
#  2   japanName    3730 non-null   object
#  3   hiragana     3730 non-null   object
#  4   bust         3523 non-null   float64
#  5   waist        3539 non-null   float64
#  6   hip          3539 non-null   float64
#  7   height       3045 non-null   float64
#  8   birthday     3056 non-null   datetime64[ns]
#  9   blood_type   2610 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  2665 non-null   object
#  12  age          3056 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(6)
# memory usage: 408.0+ KB

# %%
hobby_txt = ''.join(hobby_df['hobby'])

# %%
from matplotlib import rcParams
rcParams['figure.figsize'] = 15,8
wordcloud = WordCloud(font_path='jav-py/jp.otf', max_words=200, max_font_size=40, scale=3).generate(hobby_txt)

# %%
plt.imshow(wordcloud)
plt.axis('off')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn import metrics
import warnings
warnings.filterwarnings("ignore")

# %%
#Read Json file
df_actress = pd.read_json("jav-py/acctress.json")
df_actress.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   id           11186 non-null  int64
#  1   name         11186 non-null  object
#  2   japanName    11186 non-null  object
#  3   hiragana     11186 non-null  object
#  4   bust         6456 non-null   float64
#  5   waist        6436 non-null   float64
#  6   hip          6428 non-null   float64
#  7   height       5012 non-null   float64
#  8   birthday     4031 non-null   object
#  9   blood_type   3171 non-null   object
#  10  hobby        3730 non-null   object
#  11  prefectures  4471 non-null   object
# dtypes: float64(4), int64(1), object(7)
# memory usage: 1.0+ MB

# %%
df_test = df_actress[['bust', 'waist', 'hip', 'height', 'blood_type']]
df_test.head()
# Out:
#    bust  waist   hip  height blood_type
# 0  95.0   60.0  88.0     NaN         AB
# 1  90.0   58.0  86.0   157.0          A
# 2  96.0   55.0  85.0   168.0          B
# 3  80.0   59.0  82.0   162.0          O
# 4  82.0   55.0  89.0   162.0          A

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11186 entries, 0 to 11185
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bust        6456 non-null   float64
#  1   waist       6436 non-null   float64
#  2   hip         6428 non-null   float64
#  3   height      5012 non-null   float64
#  4   blood_type  3171 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 437.1+ KB

# %%
df_test = df_test.dropna()
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2678 entries, 1 to 11185
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   bust        2678 non-null   float64
#  1   waist       2678 non-null   float64
#  2   hip         2678 non-null   float64
#  3   height      2678 non-null   float64
#  4   blood_type  2678 non-null   object
# dtypes: float64(4), object(1)
# memory usage: 125.5+ KB

# %%
df.blood_type.value_counts()
# Out:
# A     1303
# O     1121
# B      500
# AB     247
# Name: blood_type, dtype: int64

# %%
mapper = {'O': 0, 'A': 1, 'B': 2, 'AB': 3}
df_test['blood_type'] = df_test['blood_type'].map(mapper)
df_test.head()
# Out:
#    bust  waist   hip  height  blood_type
# 1  90.0   58.0  86.0   157.0           1
# 2  96.0   55.0  85.0   168.0           2
# 3  80.0   59.0  82.0   162.0           0
# 4  82.0   55.0  89.0   162.0           1
# 6  85.0   60.0  88.0   165.0           1

# %%
actress_np = df_test.to_numpy()
actress_np
# Out:
# array([[ 90.,  58.,  86., 157.,   1.],
#        [ 96.,  55.,  85., 168.,   2.],
#        [ 80.,  59.,  82., 162.,   0.],
#        ...,
#        [ 83.,  58.,  85., 165.,   0.],
#        [ 88.,  58.,  87., 153.,   0.],
#        [ 88.,  59.,  86., 161.,   2.]])

# %%
k_mean_5 = KMeans(n_clusters= 5)
k_mean_5.fit(actress_np)
label_5 = k_mean_5.labels_

# %%
label_5
# Out:
# array([3, 2, 0, ..., 2, 3, 3], dtype=int32)

# %%
k_mean_10 = KMeans(n_clusters= 10)
k_mean_10.fit(actress_np)
label_10 = k_mean_10.labels_
label_10
# Out:
# array([1, 7, 2, ..., 2, 3, 5], dtype=int32)

# %%
metrics.silhouette_score(actress_np, label_10, metric='euclidean')
# Out:
# 0.20272490916120342

# %%
metrics.calinski_harabasz_score(actress_np, label_5)
# Out:
# 1065.3871120369677

# %%
sum_distances = []
K = range(1, 15)
for k in K:
  k_mean = KMeans(n_clusters=k)
  k_mean.fit(actress_np)
  sum_distances.append(k_mean.inertia_)

# %%
plt.plot(K, sum_distances, 'bx-')
plt.show()

# %%
k_mean_3 = KMeans(n_clusters= 3)
model= k_mean_3.fit(actress_np)
result = k_mean_3.labels_

# %%
result
# Out:
# array([0, 1, 2, ..., 2, 0, 2], dtype=int32)

# %%
plt.scatter(actress_np[:, 0], actress_np[:, 3])
plt.show()

# %%
plt.scatter(
    actress_np[result == 0, 0], actress_np[result == 0, 3],
    c='lightgreen',
    marker='s', edgecolor='black', 
    label='cluster 1'
)
plt.scatter(
    actress_np[result == 1, 0], actress_np[result == 1, 3],
    c='orange',
    marker='o', edgecolor='black', 
    label='cluster 2'
)
plt.scatter(
    actress_np[result == 2, 0], actress_np[result == 2, 3],
    c='lightblue',
    marker='v', edgecolor='black', 
    label='cluster 3'
)
plt.scatter(
    model.cluster_centers_[:,0], model.cluster_centers_[:,3],
    c='red', s=250,
    marker='*',
    label ='centroids'
)
plt.legend(scatterpoints=1)
plt.grid()
plt.show()

# %%
df1 = actress[['id', 'bust', 'waist', 'hip', 'height', 'blood_type']]
df1 = df1.dropna()
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2678 entries, 1 to 11185
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2678 non-null   int64
#  1   bust        2678 non-null   float64
#  2   waist       2678 non-null   float64
#  3   hip         2678 non-null   float64
#  4   height      2678 non-null   float64
#  5   blood_type  2678 non-null   object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 146.5+ KB

# %%
df2 = actress[['id', 'name', 'japanName']]
df2.head()
# Out:
#    id          name japanName
# 0   3  Kitagawa Yui      北川ゆい
# 1   4         Akira     Akira
# 2   6        Cocolo    COCOLO
# 3   8         Saiko     Saiko
# 4  11     Aida Momo     あいだもも

# %%
lookup = df1.merge(df2, on='id', how='left')
lookup.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2678 entries, 0 to 2677
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          2678 non-null   int64
#  1   bust        2678 non-null   float64
#  2   waist       2678 non-null   float64
#  3   hip         2678 non-null   float64
#  4   height      2678 non-null   float64
#  5   blood_type  2678 non-null   object
#  6   name        2678 non-null   object
#  7   japanName   2678 non-null   object
# dtypes: float64(4), int64(1), object(3)
# memory usage: 188.3+ KB

# %%
lookup['cluster'] = result
lookup.head()
# Out:
#    id  bust  waist   hip  height blood_type        name japanName  cluster
# 0   4  90.0   58.0  86.0   157.0          A       Akira     Akira        0
# 1   6  96.0   55.0  85.0   168.0          B      Cocolo    COCOLO        1
# 2   8  80.0   59.0  82.0   162.0          O       Saiko     Saiko        2
# 3  11  82.0   55.0  89.0   162.0          A   Aida Momo     あいだもも        2
# 4  17  85.0   60.0  88.0   165.0          A  Aduki Miyu     あづき美由        2

# %%
def recommend(model, vong1, vong2, vong3, chieu_cao, nhom_mau):
  arr = np.array([[vong1, vong2, vong3, chieu_cao, nhom_mau]])
  pred = model.predict(arr)
  return lookup[lookup['cluster'] == pred[0]].sample(10)

# %%
vong1 = 86
vong2 = 55
vong3 = 90
chieu_cao = 160
nhom_mau = 0

recommend(model, vong1, vong2, vong3, chieu_cao, nhom_mau)
# Out:
#            id  bust  waist   hip  height blood_type            name japanName  \
# 953      2458  88.0   57.0  86.0   160.0          A    Momoi Natumi     桃井なつみ
# 50        179  87.0   58.0  88.0   162.0          O      Misaki Rie     みさき理絵
# 1647  1015917  82.0   59.0  84.0   161.0          O    Nakano Erika     中野えりか
# 319     14603  86.0   60.0  90.0   168.0          B     Aikawa Nana      相川奈々
# 585     18848  87.0   58.0  87.0   166.0         AB     Sano Kyouko      佐野恭子
# 434     16712  84.0   60.0  83.0   160.0          O   Karasawa Miki      唐沢美樹
# 1324     3041  80.0   56.0  83.0   160.0          A    Hayama Reiko     葉山レイコ
# 1294  1001667  90.0   62.0  85.0   170.0          A  Siraisi Misaki      白石美咲
# 430     16675  85.0   58.0  88.0   158.0          A         Ai Miko       愛みこ
# 2526      851  84.0   58.0  88.0   167.0          A  Kousaka Yukari     香坂ゆかり
#
#       cluster
# 953         2
# 50          2
# 1647        2
# 319         2
# 585         2
# 434         2
# 1324        2
# 1294        2
# 430         2
# 2526        2
